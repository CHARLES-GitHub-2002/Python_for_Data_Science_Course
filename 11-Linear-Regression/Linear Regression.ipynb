# %% [markdown]
# # importing the libraries

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import sklearn.datasets
import xgboost as xg

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics 
from xgboost import XGBRegressor

# %% [markdown]
# ### Importing the Boston Houuse prices  dataset

# %%
df=pd.read_csv(r"C:\Users\Charles\Downloads\BOSTON DATASET\BostonHousing.csv")

# %%
df.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'b', 'lstat', 'medv'],
#       dtype='object')

# %%
df.rename(columns={'crim':'crime rate',
                  'zn':'zoned',
                  'indus':'indus',
                  'chas':'chas',
                  'nox':'Nitric oxide conc',
                  'rm':'number of rooms', 
                    'medv':'price'},inplace=True)

# %%
df.columns
# Out:
# Index(['crime rate', 'zoned', 'indus', 'chas', 'Nitric oxide conc',
#        'number of rooms', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat',
#        'price'],
#       dtype='object')

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# crime rate           0
# zoned                0
# indus                0
# chas                 0
# Nitric oxide conc    0
# number of rooms      5
# age                  0
# dis                  0
# rad                  0
# tax                  0
# ptratio              0
# b                    0
# lstat                0
# price                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# crime rate           0
# zoned                0
# indus                0
# chas                 0
# Nitric oxide conc    0
# number of rooms      0
# age                  0
# dis                  0
# rad                  0
# tax                  0
# ptratio              0
# b                    0
# lstat                0
# price                0
# dtype: int64

# %%
df.describe()
# Out:
#        crime rate       zoned       indus        chas  Nitric oxide conc  \
# count  501.000000  501.000000  501.000000  501.000000         501.000000
# mean     3.647414   11.402196   11.160619    0.069860           0.555151
# std      8.637688   23.414214    6.857123    0.255166           0.116186
# min      0.006320    0.000000    0.460000    0.000000           0.385000
# 25%      0.081990    0.000000    5.190000    0.000000           0.449000
# 50%      0.261690    0.000000    9.690000    0.000000           0.538000
# 75%      3.693110   12.500000   18.100000    0.000000           0.624000
# max     88.976200  100.000000   27.740000    1.000000           0.871000
#
#        number of rooms         age         dis         rad         tax  \
# count       501.000000  501.000000  501.000000  501.000000  501.000000
# mean          6.284341   68.513373    3.786423    9.596806  409.143713
# std           0.705587   28.212221    2.103327    8.735509  169.021216
# ...

# %% [markdown]
# ### Understanding the data

# %%
# coreration btwn diffrent column in the dataset
